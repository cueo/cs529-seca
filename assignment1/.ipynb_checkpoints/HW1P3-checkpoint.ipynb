# %%
import numpy as np

with open('data.txt') as f:
    lines = f.readlines()

X = []
Y = []
for line in lines:
    line = line.strip()
    values = line.split()
    x, y = values[0], values[-1]
    X.append(x)
    Y.append(y)

X = np.array(X)
Y = np.array(Y)
print(X, Y)
# Out:
# ['-6.0000000e+000' '-5.8000000e+000' '-5.6000000e+000' '-5.4000000e+000'
#  '-5.2000000e+000' '-5.0000000e+000' '-4.8000000e+000' '-4.6000000e+000'
#  '-4.4000000e+000' '-4.2000000e+000' '-4.0000000e+000' '-3.8000000e+000'
#  '-3.6000000e+000' '-3.4000000e+000' '-3.2000000e+000' '-3.0000000e+000'
#  '-2.8000000e+000' '-2.6000000e+000' '-2.4000000e+000' '-2.2000000e+000'
#  '-2.0000000e+000' '-1.8000000e+000' '-1.6000000e+000' '-1.4000000e+000'
#  '-1.2000000e+000' '-1.0000000e+000' '-8.0000000e-001' '-6.0000000e-001'
#  '-4.0000000e-001' '-2.0000000e-001' '0.0000000e+000' '2.0000000e-001'
#  '4.0000000e-001' '6.0000000e-001' '8.0000000e-001' '1.0000000e+000'
#  '1.2000000e+000' '1.4000000e+000' '1.6000000e+000' '1.8000000e+000'
#  '2.0000000e+000' '2.2000000e+000' '2.4000000e+000' '2.6000000e+000'
#  '2.8000000e+000' '3.0000000e+000' '3.2000000e+000' '3.4000000e+000'
#  '3.6000000e+000' '3.8000000e+000' '4.0000000e+000' '4.2000000e+000'
# ...
